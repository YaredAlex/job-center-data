# %%
import pandas as pd

# %%
df_hawi = pd.read_csv('mapped_Hawi.csv')
df_tibarek = pd.read_csv('mapped_Tibarek_Final.csv')

# %%
df_combined = pd.concat((df_hawi,df_tibarek))
df_combined.head()
# Out:
#               informal work in eng Profession  in Amharic  \
# 0         Electronics Sales Worker     የኤሌክትሮኒክስ ሽያጭ ሰራተኛ
# 1                  Executive issue              ጉዳይ አስፈፃሚ
# 2  Vehicle distribution specialist    የተሽከርካሪዎች ስምሪት ባለሙያ
# 3                CBE Birr Operator           ሲቢኢ ብር ኦፕሬተር
# 4       project and marketing head      ፕሮጀክት እና ግብይት ኃላፊ
#
#   Professional / Informal sector sub sector Profession in Amharic  \
# 0                       P    NaN        NaN                   NaN
# 1                       P    NaN        NaN                   NaN
# 2                       P    NaN        NaN                   NaN
# 3                       P    NaN        NaN                   NaN
# 4                       P    NaN        NaN                   NaN
#
#   professional/ formal
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df_combined.to_csv("9k_positions.csv",index=False)
